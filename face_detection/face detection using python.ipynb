# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading mtcnn-0.1.0-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 750 kB/s eta 0:00:01
# Requirement already satisfied: opencv-python>=4.1.0 in /home/dhananjaya/anaconda3/lib/python3.8/site-packages (from mtcnn) (4.5.1.48)
# Requirement already satisfied: keras>=2.0.0 in /home/dhananjaya/anaconda3/lib/python3.8/site-packages (from mtcnn) (2.4.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/dhananjaya/anaconda3/lib/python3.8/site-packages (from opencv-python>=4.1.0->mtcnn) (1.19.5)
# Requirement already satisfied: pyyaml in /home/dhananjaya/anaconda3/lib/python3.8/site-packages (from keras>=2.0.0->mtcnn) (5.3.1)
# Requirement already satisfied: h5py in /home/dhananjaya/anaconda3/lib/python3.8/site-packages (from keras>=2.0.0->mtcnn) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /home/dhananjaya/anaconda3/lib/python3.8/site-packages (from keras>=2.0.0->mtcnn) (1.5.0)
# Requirement already satisfied: six in /home/dhananjaya/anaconda3/lib/python3.8/site-packages (from h5py->keras>=2.0.0->mtcnn) (1.15.0)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.0

# %%
from mtcnn import MTCNN
import cv2
detector = MTCNN()
#Load a video
video_capture = cv2.VideoCapture(0)
 
while (True):
    ret, frame = video_capture.read()
    frame = cv2.resize(frame, (600, 400))
    boxes = detector.detect_faces(frame)
    if boxes:
 
        box = boxes[0]['box']
        conf = boxes[0]['confidence']
        x, y, w, h = box[0], box[1], box[2], box[3]
 
        if conf > 0.5:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 255, 255), 1)
 
    cv2.imshow("Frame", frame)
    key=cv2.waitKey(25) & 0xFF 
    if key == ord('q'):
        break
 
video_capture.release()
cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:5 out of the last 120 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd140284160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
import cv2
import matplotlib.pyplot as plt
image=cv2.imread('/home/dhananjaya/Downloads/yoda.jpg')
plt.imshow(image)

# %%
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
resize=cv2.resize(image,(400,400))
plt.imshow(resize)
